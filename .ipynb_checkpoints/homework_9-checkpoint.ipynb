# %%
# !pip install tensorflow_datasets >> None
# Out:
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Deic\anaconda\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.

# %%
import numpy as np
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\Users\Deic\anaconda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keras.datasets import fashion_mnist

(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()

# %%
print(train_data.shape)
print(len(train_labels))
print(train_labels)
print(test_data.shape)
print(len(test_labels))
# Out:
# (60000, 28, 28)
# 60000
# [9 0 0 ... 3 0 5]
# (10000, 28, 28)
# 10000

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(train_data[0])
plt.colorbar()

plt.show()

# %%
# Now we have our data values from 0 to 1
train_data = train_data / 255.0

test_data = test_data / 255.0

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_data[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Let's expirement with the Neural Network params

# %% [markdown]
# ### First let's see how many layers and neurons do we need

# %%
# Basic 3 neruon model
base_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %%
more_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %%
# At this moment I'll use the "adam" optimizer for both models
base_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

more_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Let's train our models

print("base_model")
print("-----")
base_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
print("-----")
print("more_model")
print("-----")
more_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
# Out:
# base_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 3ms/step - loss: 0.8388 - accuracy: 0.7240
# Epoch 2/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5046 - accuracy: 0.8274
# Epoch 3/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4512 - accuracy: 0.8458
# Epoch 4/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4217 - accuracy: 0.8553
# Epoch 5/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8613
# Epoch 6/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.8665
# Epoch 7/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3690 - accuracy: 0.8708
# Epoch 8/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3628 - accuracy: 0.8732
# Epoch 9/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3540 - accuracy: 0.8753
# Epoch 10/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3416 - accuracy: 0.8791
# -----
# more_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 4ms/step - loss: 0.8444 - accuracy: 0.7197
# Epoch 2/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4765 - accuracy: 0.8336
# Epoch 3/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8487
# Epoch 4/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3911 - accuracy: 0.8634
# Epoch 5/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3678 - accuracy: 0.8707
# Epoch 6/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3524 - accuracy: 0.8751
# Epoch 7/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3371 - accuracy: 0.8810
# Epoch 8/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3262 - accuracy: 0.8840
# Epoch 9/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3150 - accuracy: 0.8869
# Epoch 10/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3024 - accuracy: 0.8916

# %%
test_loss_base, test_acc_base = base_model.evaluate(test_data, test_labels, verbose=2)

test_loss_more, test_acc_more = more_model.evaluate(test_data, test_labels, verbose=2)

print('\nTest accuracy for base:', test_acc_base)

print('\nTest accuracy for more:', test_acc_more)
# Out:
# 313/313 - 0s - loss: 0.3823 - accuracy: 0.8660 - 295ms/epoch - 943us/step
# 313/313 - 0s - loss: 0.3553 - accuracy: 0.8756 - 313ms/epoch - 1000us/step
#
# Test accuracy for base: 0.8659999966621399
#
# Test accuracy for more: 0.8755999803543091

# %% [markdown]
# ### As we can see even at 10 epochs loss and accuracy is better on the NN with more layers

# %%
# Let's expirement with neurons
base_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)    
])

more_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

less_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10)
])

# %%
base_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

more_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

less_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("base_model")
print("-----")
base_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
print("-----")
print("more_model")
print("-----")
more_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
print("-----")
print("base_model")
print("-----")
less_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
# Out:
# base_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 5ms/step - loss: 0.8251 - accuracy: 0.7301
# Epoch 2/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4688 - accuracy: 0.8366
# Epoch 3/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4175 - accuracy: 0.8545
# Epoch 4/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3869 - accuracy: 0.8633
# Epoch 5/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8692
# Epoch 6/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8770
# Epoch 7/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3364 - accuracy: 0.8801
# Epoch 8/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3313 - accuracy: 0.8825
# Epoch 9/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.8859
# Epoch 10/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3105 - accuracy: 0.8879
# -----
# more_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 0.7229 - accuracy: 0.7573
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4368 - accuracy: 0.8472
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3909 - accuracy: 0.8623
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3606 - accuracy: 0.8705
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3377 - accuracy: 0.8787
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3172 - accuracy: 0.8850
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3037 - accuracy: 0.8894
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2929 - accuracy: 0.8935
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2788 - accuracy: 0.8981
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2733 - accuracy: 0.9004
# -----
# base_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 3ms/step - loss: 0.9629 - accuracy: 0.6794
# Epoch 2/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5186 - accuracy: 0.8226
# Epoch 3/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.8427
# Epoch 4/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4230 - accuracy: 0.8518
# Epoch 5/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3970 - accuracy: 0.8616
# Epoch 6/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8655
# Epoch 7/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3747 - accuracy: 0.8677
# Epoch 8/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3598 - accuracy: 0.8741
# Epoch 9/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3479 - accuracy: 0.8773
# Epoch 10/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3419 - accuracy: 0.8794

# %%
test_loss_base, test_acc_base = base_model.evaluate(test_data, test_labels, verbose=2)

test_loss_more, test_acc_more = more_model.evaluate(test_data, test_labels, verbose=2)

test_loss_less, test_acc_less = less_model.evaluate(test_data, test_labels, verbose=2)

print('\nTest accuracy for base:', test_acc_base)

print('\nTest accuracy for more:', test_acc_more)

print('\nTest accuracy for less:', test_acc_less)
# Out:
# 313/313 - 0s - loss: 0.3551 - accuracy: 0.8744 - 317ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3476 - accuracy: 0.8784 - 352ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3892 - accuracy: 0.8628 - 294ms/epoch - 941us/step
#
# Test accuracy for base: 0.8744000196456909
#
# Test accuracy for more: 0.8784000277519226
#
# Test accuracy for less: 0.8628000020980835

# %% [markdown]
# ### Model with more neurons has better results, so we'll use it for the next experiments

# %%
base_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

softmax_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='softmax'),
    keras.layers.Dense(256, activation='softmax'),
    keras.layers.Dense(10)
])

tanh_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(10)
])

# %%
base_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

softmax_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

tanh_model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("base_model")
print("-----")
base_model.fit(train_data, train_labels, batch_size=1024, epochs=10) 
print("-----")
print("softmax_model")
print("-----")
softmax_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
print("-----")
print("tanh_model")
print("-----")
tanh_model.fit(train_data, train_labels, batch_size=1024, epochs=10)
# Out:
# base_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 0.7156 - accuracy: 0.7600
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4332 - accuracy: 0.8472
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3907 - accuracy: 0.8614
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3547 - accuracy: 0.8752
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3404 - accuracy: 0.8791
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3162 - accuracy: 0.8869
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3043 - accuracy: 0.8907
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2903 - accuracy: 0.8958
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2791 - accuracy: 0.8980
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2727 - accuracy: 0.9006
# -----
# softmax_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 7ms/step - loss: 2.3023 - accuracy: 0.1113
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.2976 - accuracy: 0.3418
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.2840 - accuracy: 0.5530
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.2563 - accuracy: 0.5612
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.2118 - accuracy: 0.5629
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.1522 - accuracy: 0.5663
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.0815 - accuracy: 0.5666
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 2.0042 - accuracy: 0.5669
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 1.9231 - accuracy: 0.5694
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 1.8403 - accuracy: 0.5704
# -----
# tanh_model
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 7ms/step - loss: 0.6960 - accuracy: 0.7547
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4380 - accuracy: 0.8438
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3994 - accuracy: 0.8568
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3762 - accuracy: 0.8648
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3536 - accuracy: 0.8725
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3374 - accuracy: 0.8775
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3289 - accuracy: 0.8806
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3160 - accuracy: 0.8848
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3039 - accuracy: 0.8893
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2945 - accuracy: 0.8936

# %%
test_loss_base, test_acc_base = base_model.evaluate(test_data, test_labels, verbose=2)

test_loss_softmax, test_acc_softmax = softmax_model.evaluate(test_data, test_labels, verbose=2)

test_loss_tanh, test_acc_tanh = tanh_model.evaluate(test_data, test_labels, verbose=2)

print('\nTest accuracy for base:', test_acc_base)

print('\nTest accuracy for softmax:', test_acc_softmax)

print('\nTest accuracy for tanh:', test_acc_tanh)
# Out:
# 313/313 - 0s - loss: 0.3366 - accuracy: 0.8822 - 353ms/epoch - 1ms/step
# 313/313 - 0s - loss: 1.8016 - accuracy: 0.5656 - 408ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3694 - accuracy: 0.8644 - 389ms/epoch - 1ms/step
#
# Test accuracy for base: 0.8822000026702881
#
# Test accuracy for softmax: 0.5655999779701233
#
# Test accuracy for tanh: 0.8644000291824341

# %% [markdown]
# ### *relu* Shows the best results

# %% [markdown]
# ### Let's expirements with optimizers

# %%
model_adam = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_lion = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_sgd = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

# %%
from keras.optimizers import Lion
model_adam.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_lion.compile(optimizer=Lion(),
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_sgd.compile(optimizer='sgd',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("Adam")
print("-----")
model_adam.fit(train_data, train_labels, batch_size=1024, epochs=10) 
print("-----")
print("Lion")
print("-----")
model_lion.fit(train_data, train_labels, batch_size=1024, epochs=10)
print("-----")
print("SGD")
print("-----")
model_sgd.fit(train_data, train_labels, batch_size=1024, epochs=10)
# Out:
# Adam
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 0.7385 - accuracy: 0.7527
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4358 - accuracy: 0.8484
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3891 - accuracy: 0.8624
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3577 - accuracy: 0.8725
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3307 - accuracy: 0.8819
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3175 - accuracy: 0.8858
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3017 - accuracy: 0.8910
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2914 - accuracy: 0.8943
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2825 - accuracy: 0.8968
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2745 - accuracy: 0.8995
# -----
# Lion
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 1.5833 - accuracy: 0.5440
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7738 - accuracy: 0.7354
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6139 - accuracy: 0.7919
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5273 - accuracy: 0.8194
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4746 - accuracy: 0.8357
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4400 - accuracy: 0.8459
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4145 - accuracy: 0.8543
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3947 - accuracy: 0.8608
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3770 - accuracy: 0.8668
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3625 - accuracy: 0.8722
# -----
# SGD
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 1.9618 - accuracy: 0.4250
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 1.4171 - accuracy: 0.6295
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 1.1130 - accuracy: 0.6683
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.9569 - accuracy: 0.6979
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.8665 - accuracy: 0.7205
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.8061 - accuracy: 0.7393
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.7621 - accuracy: 0.7521
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.7276 - accuracy: 0.7631
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6997 - accuracy: 0.7718
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6758 - accuracy: 0.7803

# %% [markdown]
# ### *adam* shows the best results for our model

# %% [markdown]
# ### Let's take different batch sizes and epochs

# %%
model_base = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_less = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_more = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

# %%
model_base.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_less.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_more.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("base")
print("-----")
model_base.fit(train_data, train_labels, batch_size=1024, epochs=10) 
print("-----")
print("less")
print("-----")
model_less.fit(train_data, train_labels, batch_size=4096, epochs=10)
print("-----")
print("more")
print("-----")
model_more.fit(train_data, train_labels, batch_size=256, epochs=10)
print("-----")
print("default batch_size")
print("-----")
model.fit(train_data, train_labels, epochs=10)
# Out:
# base
# -----
# Epoch 1/10
# 59/59 [==============================] - 1s 6ms/step - loss: 0.7170 - accuracy: 0.7614
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4376 - accuracy: 0.8471
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3910 - accuracy: 0.8634
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3565 - accuracy: 0.8734
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3426 - accuracy: 0.8772
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3179 - accuracy: 0.8857
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2985 - accuracy: 0.8928
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2921 - accuracy: 0.8928
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2795 - accuracy: 0.8979
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2708 - accuracy: 0.9017
# -----
# less
# -----
# Epoch 1/10
# 15/15 [==============================] - 1s 15ms/step - loss: 1.2072 - accuracy: 0.6141
# Epoch 2/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6077 - accuracy: 0.7899
# Epoch 3/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5057 - accuracy: 0.8241
# Epoch 4/10
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4622 - accuracy: 0.8386
# Epoch 5/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4284 - accuracy: 0.8512
# Epoch 6/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4078 - accuracy: 0.8575
# Epoch 7/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4016 - accuracy: 0.8587
# Epoch 8/10
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3827 - accuracy: 0.8657
# Epoch 9/10
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3664 - accuracy: 0.8714
# Epoch 10/10
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3532 - accuracy: 0.8755
# -----
# more
# -----
# Epoch 1/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5450 - accuracy: 0.8097
# Epoch 2/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3781 - accuracy: 0.8645
# Epoch 3/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3382 - accuracy: 0.8776
# Epoch 4/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3104 - accuracy: 0.8863
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2873 - accuracy: 0.8934
# Epoch 6/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2742 - accuracy: 0.8983
# Epoch 7/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2612 - accuracy: 0.9024
# Epoch 8/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2507 - accuracy: 0.9064
# Epoch 9/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2391 - accuracy: 0.9108
# Epoch 10/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2288 - accuracy: 0.9140
# -----
# default batch_size
# -----
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4708 - accuracy: 0.8300
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3580 - accuracy: 0.8696
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3239 - accuracy: 0.8803
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3026 - accuracy: 0.8878
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2837 - accuracy: 0.8936
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2681 - accuracy: 0.8985
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2549 - accuracy: 0.9038
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2434 - accuracy: 0.9077
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2324 - accuracy: 0.9119
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2254 - accuracy: 0.9146

# %% [markdown]
# ### Accuracy and loss of default batch_size and batch_size=256 almost the same, but with batch_size=256 model trains much faster

# %%
model_base = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(10)
])

model_more = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_emore = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

# %%
model_base.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_more.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_emore.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("base")
print("-----")
model_base.fit(train_data, train_labels, batch_size=256, epochs=10) 
print("-----")
print("more")
print("-----")
model_more.fit(train_data, train_labels, batch_size=256, epochs=20)
print("-----")
print("even_more")
print("-----")
model_emore.fit(train_data, train_labels, batch_size=256, epochs=40)
# Out:
# base
# -----
# Epoch 1/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5187 - accuracy: 0.8143
# Epoch 2/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3629 - accuracy: 0.8687
# Epoch 3/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3275 - accuracy: 0.8787
# Epoch 4/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3031 - accuracy: 0.8874
# Epoch 5/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2821 - accuracy: 0.8953
# Epoch 6/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2658 - accuracy: 0.9014
# Epoch 7/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2568 - accuracy: 0.9038
# Epoch 8/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2417 - accuracy: 0.9093
# Epoch 9/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2346 - accuracy: 0.9123
# Epoch 10/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2226 - accuracy: 0.9174
# -----
# more
# -----
# Epoch 1/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5438 - accuracy: 0.8122
# Epoch 2/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3786 - accuracy: 0.8633
# Epoch 3/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3353 - accuracy: 0.8773
# Epoch 4/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3097 - accuracy: 0.8863
# Epoch 5/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2898 - accuracy: 0.8931
# Epoch 6/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2736 - accuracy: 0.8986
# Epoch 7/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2607 - accuracy: 0.9029
# Epoch 8/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2479 - accuracy: 0.9083
# Epoch 9/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2369 - accuracy: 0.9116
# Epoch 10/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2300 - accuracy: 0.9138
# Epoch 11/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2184 - accuracy: 0.9178
# Epoch 12/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2071 - accuracy: 0.9227
# Epoch 13/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2019 - accuracy: 0.9237
# Epoch 14/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1915 - accuracy: 0.9283
# Epoch 15/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1887 - accuracy: 0.9294
# Epoch 16/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1792 - accuracy: 0.9325
# Epoch 17/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1742 - accuracy: 0.9345
# Epoch 18/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1681 - accuracy: 0.9372
# Epoch 19/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1649 - accuracy: 0.9375
# Epoch 20/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1543 - accuracy: 0.9412
# -----
# even_more
# -----
# Epoch 1/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5478 - accuracy: 0.8080
# Epoch 2/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3796 - accuracy: 0.8649
# Epoch 3/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3380 - accuracy: 0.8788
# Epoch 4/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3110 - accuracy: 0.8868
# Epoch 5/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2884 - accuracy: 0.8940
# Epoch 6/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2723 - accuracy: 0.8990
# Epoch 7/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2632 - accuracy: 0.9011
# Epoch 8/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2498 - accuracy: 0.9071
# Epoch 9/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2379 - accuracy: 0.9105
# Epoch 10/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2250 - accuracy: 0.9156
# Epoch 11/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9183
# Epoch 12/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2092 - accuracy: 0.9227
# Epoch 13/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2057 - accuracy: 0.9226
# Epoch 14/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1954 - accuracy: 0.9263
# Epoch 15/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1876 - accuracy: 0.9287
# Epoch 16/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1792 - accuracy: 0.9323
# Epoch 17/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1746 - accuracy: 0.9342
# Epoch 18/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1686 - accuracy: 0.9369
# Epoch 19/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1602 - accuracy: 0.9396
# Epoch 20/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1577 - accuracy: 0.9396
# Epoch 21/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1526 - accuracy: 0.9415
# Epoch 22/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1461 - accuracy: 0.9445
# Epoch 23/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1412 - accuracy: 0.9468
# Epoch 24/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1363 - accuracy: 0.9479
# Epoch 25/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1328 - accuracy: 0.9492
# Epoch 26/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1240 - accuracy: 0.9535
# Epoch 27/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1254 - accuracy: 0.9531
# Epoch 28/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1203 - accuracy: 0.9559
# Epoch 29/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1184 - accuracy: 0.9554
# Epoch 30/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1098 - accuracy: 0.9584
# Epoch 31/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1078 - accuracy: 0.9591
# Epoch 32/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1004 - accuracy: 0.9629
# Epoch 33/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0961 - accuracy: 0.9639
# Epoch 34/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0989 - accuracy: 0.9623
# Epoch 35/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0887 - accuracy: 0.9667
# Epoch 36/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0888 - accuracy: 0.9663
# Epoch 37/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0877 - accuracy: 0.9669
# Epoch 38/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0857 - accuracy: 0.9680
# Epoch 39/40
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0829 - accuracy: 0.9684
# Epoch 40/40
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0836 - accuracy: 0.9689

# %%
test_loss_base, test_acc_base = model_base.evaluate(test_data, test_labels, verbose=2)

test_loss_more, test_acc_more = model_more.evaluate(test_data, test_labels, verbose=2)

test_loss_emore, test_acc_emore = model_emore.evaluate(test_data, test_labels, verbose=2)

print('\nTest accuracy for base:', test_acc_base)

print('\nTest accuracy for more:', test_acc_more)

print('\nTest accuracy for even more:', test_acc_emore)
# Out:
# 313/313 - 0s - loss: 0.3313 - accuracy: 0.8835 - 366ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.3519 - accuracy: 0.8851 - 363ms/epoch - 1ms/step
# 313/313 - 0s - loss: 0.4578 - accuracy: 0.8927 - 352ms/epoch - 1ms/step
#
# Test accuracy for base: 0.8834999799728394
#
# Test accuracy for more: 0.8851000070571899
#
# Test accuracy for even more: 0.8927000164985657

# %% [markdown]
# ## As we can see model with epochs = 40 shows better accuracy, but our loss is already increasing, so we need to be very carefull

# %% [markdown]
# ### Let's try to use regularizer

# %%
model_base = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

model_regularized = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01)),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01)),
    keras.layers.Dense(10)
])

# %%
model_base.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_regularized.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print("base")
print("-----")
model_base.fit(train_data, train_labels, batch_size=256, epochs=20) 
print("-----")
print("more")
print("-----")
model_regularized.fit(train_data, train_labels, batch_size=256, epochs=20)
# Out:
# base
# -----
# Epoch 1/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5515 - accuracy: 0.8087
# Epoch 2/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3788 - accuracy: 0.8646
# Epoch 3/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3330 - accuracy: 0.8795
# Epoch 4/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3091 - accuracy: 0.8874
# Epoch 5/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2896 - accuracy: 0.8935
# Epoch 6/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2719 - accuracy: 0.8995
# Epoch 7/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2590 - accuracy: 0.9042
# Epoch 8/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2492 - accuracy: 0.9079
# Epoch 9/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2363 - accuracy: 0.9113
# Epoch 10/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2240 - accuracy: 0.9172
# Epoch 11/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2185 - accuracy: 0.9179
# Epoch 12/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2115 - accuracy: 0.9216
# Epoch 13/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2011 - accuracy: 0.9249
# Epoch 14/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1924 - accuracy: 0.9269
# Epoch 15/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1891 - accuracy: 0.9293
# Epoch 16/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1753 - accuracy: 0.9352
# Epoch 17/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1738 - accuracy: 0.9340
# Epoch 18/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1663 - accuracy: 0.9382
# Epoch 19/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1612 - accuracy: 0.9398
# Epoch 20/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1551 - accuracy: 0.9420
# -----
# more
# -----
# Epoch 1/20
# 235/235 [==============================] - 1s 3ms/step - loss: 2.2369 - accuracy: 0.7876
# Epoch 2/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8013 - accuracy: 0.8198
# Epoch 3/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6887 - accuracy: 0.8259
# Epoch 4/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.6445 - accuracy: 0.8315
# Epoch 5/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.6191 - accuracy: 0.8354
# Epoch 6/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.6069 - accuracy: 0.8368
# Epoch 7/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5844 - accuracy: 0.8437
# Epoch 8/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5786 - accuracy: 0.8434
# Epoch 9/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5675 - accuracy: 0.8443
# Epoch 10/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5554 - accuracy: 0.8480
# Epoch 11/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5455 - accuracy: 0.8498
# Epoch 12/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5390 - accuracy: 0.8520
# Epoch 13/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5315 - accuracy: 0.8529
# Epoch 14/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5296 - accuracy: 0.8539
# Epoch 15/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5185 - accuracy: 0.8567
# Epoch 16/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5135 - accuracy: 0.8572
# Epoch 17/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5112 - accuracy: 0.8590
# Epoch 18/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5000 - accuracy: 0.8615
# Epoch 19/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5018 - accuracy: 0.8606
# Epoch 20/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4958 - accuracy: 0.8620

# %%
test_loss_more, test_acc_more = model_more.evaluate(test_data, test_labels, verbose=2)

test_loss_reg, test_acc_reg = model_regularized.evaluate(test_data, test_labels, verbose=2)

print('\nTest accuracy for base:', test_acc_base)

print('\nTest accuracy for regularized:', test_acc_reg)
# Out:
# 313/313 - 0s - loss: 0.3519 - accuracy: 0.8851 - 284ms/epoch - 907us/step
# 313/313 - 0s - loss: 0.5280 - accuracy: 0.8465 - 366ms/epoch - 1ms/step
#
# Test accuracy for base: 0.8834999799728394
#
# Test accuracy for regularized: 0.8464999794960022

# %% [markdown]
# ## Regularizer is not helping us

# %%
# Let's see what we got on graphics

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy', 'CategoricalCrossentropy'])

# %%
history = model.fit(train_data, train_labels, batch_size=256, epochs=20, validation_data=(test_data, test_labels))
# Out:
# Epoch 1/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5400 - accuracy: 0.8117 - val_loss: 0.4644 - val_accuracy: 0.8331
# Epoch 2/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3850 - accuracy: 0.8627 - val_loss: 0.3959 - val_accuracy: 0.8586
# Epoch 3/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3366 - accuracy: 0.8783 - val_loss: 0.3885 - val_accuracy: 0.8572
# Epoch 4/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3129 - accuracy: 0.8848 - val_loss: 0.3583 - val_accuracy: 0.8685
# Epoch 5/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2893 - accuracy: 0.8932 - val_loss: 0.3649 - val_accuracy: 0.8711
# Epoch 6/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2767 - accuracy: 0.8972 - val_loss: 0.3420 - val_accuracy: 0.8780
# Epoch 7/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2663 - accuracy: 0.9007 - val_loss: 0.3458 - val_accuracy: 0.8774
# Epoch 8/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2506 - accuracy: 0.9063 - val_loss: 0.3529 - val_accuracy: 0.8747
# Epoch 9/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2384 - accuracy: 0.9118 - val_loss: 0.3290 - val_accuracy: 0.8818
# Epoch 10/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2279 - accuracy: 0.9150 - val_loss: 0.3245 - val_accuracy: 0.8881
# Epoch 11/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2199 - accuracy: 0.9171 - val_loss: 0.3352 - val_accuracy: 0.8841
# Epoch 12/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2103 - accuracy: 0.9205 - val_loss: 0.3323 - val_accuracy: 0.8869
# Epoch 13/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2081 - accuracy: 0.9217 - val_loss: 0.3243 - val_accuracy: 0.8869
# Epoch 14/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2001 - accuracy: 0.9240 - val_loss: 0.3459 - val_accuracy: 0.8855
# Epoch 15/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1888 - accuracy: 0.9291 - val_loss: 0.3298 - val_accuracy: 0.8898
# Epoch 16/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1794 - accuracy: 0.9330 - val_loss: 0.3392 - val_accuracy: 0.8879
# Epoch 17/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1770 - accuracy: 0.9341 - val_loss: 0.3457 - val_accuracy: 0.8886
# Epoch 18/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1681 - accuracy: 0.9370 - val_loss: 0.3358 - val_accuracy: 0.8887
# Epoch 19/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1627 - accuracy: 0.9391 - val_loss: 0.3575 - val_accuracy: 0.8884
# Epoch 20/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1587 - accuracy: 0.9395 - val_loss: 0.3585 - val_accuracy: 0.8902

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, history_dict['accuracy'], 'bo', label='Training acc')
plt.plot(epochs, history_dict['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
